# %% [markdown]
# # Analyzing - Looking Into How Parks in Paradise Compare to Cities of Similar Size

# %%
processed_outdir = '/Users/kavishharjai/code/mh_paradise/processed/'

# %%
import pandas as pd 
import numpy as np
import os
import altair as alt
#import pandas and numpy libraries

# %%
pd.set_option('display.max_rows', 500)

# %%
merged = pd.read_csv(processed_outdir + 'merged.csv')
merged
# Out:
#      Unnamed: 0                             city  popestimate2018  mh_spaces
# 0             0                         Adelanto            34411      257.0
# 1             1                     Agoura Hills            20307        NaN
# 2             2                          Alameda            80196        NaN
# 3             3                           Albany            20352        NaN
# 4             4                         Alhambra            84666        NaN
# 5             5                      Aliso Viejo            50739        NaN
# 6             6                          Alturas             2530       67.0
# 7             7                      Amador City              196        NaN
# 8             8                  American Canyon            20412      843.0
# 9             9                          Anaheim           353043     3542.0
# 10           10                         Anderson            10439      691.0
# ...

# %%
merged[merged.city == 'Paradise']
# Out:
#      Unnamed: 0      city  popestimate2018  mh_spaces
# 309         309  Paradise            26532     1586.0

# %% [markdown]
# The population of Paradise in 2018 was in the high 20,000s. I will find cities that have populations within two different ranges 20k to 30k and 25k to 35k.

# %%
twenty_to_thirty = merged[(merged['popestimate2018']>= 20000) & (merged['popestimate2018'] <= 30000)]

# %%
twenty_to_thirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 1 to 481
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       57 non-null     int64
#  1   city             57 non-null     object
#  2   popestimate2018  57 non-null     int64
#  3   mh_spaces        42 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.2+ KB

# %%
twenty_to_thirty = twenty_to_thirty.dropna()

# %%
sort_spaces_twenty_to_thirty = twenty_to_thirty.sort_values('mh_spaces', ascending= False)

# %%
sort_spaces_twenty_to_thirty
# Out:
#      Unnamed: 0                city  popestimate2018  mh_spaces
# 110         110  Desert Hot Springs            29449     3277.0
# 309         309            Paradise            26532     1586.0
# 29           29             Barstow            23564     1296.0
# 346         346          Ridgecrest            28964     1078.0
# 8             8     American Canyon            20412      843.0
# 481         481        Yucca Valley            21730      772.0
# 134         134              Eureka            27009      768.0
# 418         418    South Lake Tahoe            22700      678.0
# 442         442    Twentynine Palms            26769      568.0
# 232         232          Loma Linda            24194      530.0
# 233         233              Lomita            20279      525.0
# 290         290             Oakdale            23081      479.0
# 471         471             Windsor            27979      437.0
# 99           99              Cudahy            23655      415.0
# ...

# %%
twentyf_to_thirtyf = merged[(merged['popestimate2018']>= 25000) & (merged['popestimate2018'] <= 35000)]
twentyf_to_thirtyf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 471
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       49 non-null     int64
#  1   city             49 non-null     object
#  2   popestimate2018  49 non-null     int64
#  3   mh_spaces        35 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.9+ KB

# %%
twentyf_to_thirtyf = twentyf_to_thirtyf.dropna()

# %%
sort_spaces_twentyf_to_thirtyf = twentyf_to_thirtyf.sort_values('mh_spaces', ascending= False)

# %%
sort_spaces_twentyf_to_thirtyf
# Out:
#      Unnamed: 0                city  popestimate2018  mh_spaces
# 110         110  Desert Hot Springs            29449     3277.0
# 222         222            La Verne            32324     1754.0
# 309         309            Paradise            26532     1586.0
# 346         346          Ridgecrest            28964     1078.0
# 28           28             Banning            30363      981.0
# 370         370           San Dimas            33888      906.0
# 396         396         Santa Paula            30298      775.0
# 134         134              Eureka            27009      768.0
# 385         385           San Pablo            31050      718.0
# 159         159              Goleta            32087      650.0
# 21           21             Atwater            30551      628.0
# 442         442    Twentynine Palms            26769      568.0
# 403         403             Seaside            33976      488.0
# 471         471             Windsor            27979      437.0
# ...

# %% [markdown]
# ### Conclusions
#
# * Paradise's population before the fire was ~26,532.
# * Paradise, compared to other similarly populated cities in 2018, had a high number of MH lots.
# * When compared to cities that had a population of 20,000 to 30,000, Paradise had the second highest number of MH lots.
# * When compared to cities that had a population fo 25,000 to 35,000, Paradise had the third highest number of MH lots.
# * Potential sentence for thesis:
#
#     **The town of Paradise had one of the highest number of mobile home park lots compared to cities that had a similar population in 2018.**
